# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split
import pydotplus

# %%
data=datasets.load_iris()
X_train,X_test,y_train,y_test=train_test_split(data.data,data.target,test_size=0.2,random_state=42)

# %%
clf=DecisionTreeClassifier()
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_train_pred=clf.predict(X_train)
y_test_pred=clf.predict(X_test)

# %%
plt.figure(figsize=(15,12))
plot_tree(clf,feature_names=data.feature_names,class_names=data.target_names)
# Out:
# [Text(257.53846153846155, 605.7257142857143, 'petal width (cm) <= 0.8\ngini = 0.667\nsamples = 120\nvalue = [40, 41, 39]\nclass = versicolor'),
#  Text(193.15384615384616, 512.537142857143, 'gini = 0.0\nsamples = 40\nvalue = [40, 0, 0]\nclass = setosa'),
#  Text(321.9230769230769, 512.537142857143, 'petal length (cm) <= 4.75\ngini = 0.5\nsamples = 80\nvalue = [0, 41, 39]\nclass = versicolor'),
#  Text(128.76923076923077, 419.34857142857146, 'petal width (cm) <= 1.65\ngini = 0.053\nsamples = 37\nvalue = [0, 36, 1]\nclass = versicolor'),
#  Text(64.38461538461539, 326.16, 'gini = 0.0\nsamples = 36\nvalue = [0, 36, 0]\nclass = versicolor'),
#  Text(193.15384615384616, 326.16, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(515.0769230769231, 419.34857142857146, 'petal width (cm) <= 1.75\ngini = 0.206\nsamples = 43\nvalue = [0, 5, 38]\nclass = virginica'),
#  Text(321.9230769230769, 326.16, 'petal length (cm) <= 4.95\ngini = 0.5\nsamples = 8\nvalue = [0, 4, 4]\nclass = versicolor'),
#  Text(257.53846153846155, 232.9714285714286, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(386.3076923076923, 232.9714285714286, 'petal width (cm) <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]\nclass = virginica'),
#  Text(321.9230769230769, 139.7828571428571, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = virginica'),
#  Text(450.69230769230774, 139.7828571428571, 'petal length (cm) <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = versicolor'),
#  Text(386.3076923076923, 46.594285714285775, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(515.0769230769231, 46.594285714285775, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(708.2307692307693, 326.16, 'petal length (cm) <= 4.85\ngini = 0.056\nsamples = 35\nvalue = [0, 1, 34]\nclass = virginica'),
#  Text(643.8461538461538, 232.9714285714286, 'sepal width (cm) <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(579.4615384615385, 139.7828571428571, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(708.2307692307693, 139.7828571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(772.6153846153846, 232.9714285714286, 'gini = 0.0\nsamples = 32\nvalue = [0, 0, 32]\nclass = virginica')]

# %%
clf=DecisionTreeClassifier("entropy")
clf.fit(X_train,y_train)
# Out:
# c:\users\14379\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass criterion=entropy as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# DecisionTreeClassifier(criterion='entropy')

# %%
plt.figure(figsize=(15,12))
plot_tree(clf,feature_names=data.feature_names,class_names=data.target_names)
# Out:
# [Text(257.53846153846155, 605.7257142857143, 'petal length (cm) <= 2.45\nentropy = 1.585\nsamples = 120\nvalue = [40, 41, 39]\nclass = versicolor'),
#  Text(193.15384615384616, 512.537142857143, 'entropy = 0.0\nsamples = 40\nvalue = [40, 0, 0]\nclass = setosa'),
#  Text(321.9230769230769, 512.537142857143, 'petal length (cm) <= 4.75\nentropy = 1.0\nsamples = 80\nvalue = [0, 41, 39]\nclass = versicolor'),
#  Text(128.76923076923077, 419.34857142857146, 'petal width (cm) <= 1.65\nentropy = 0.179\nsamples = 37\nvalue = [0, 36, 1]\nclass = versicolor'),
#  Text(64.38461538461539, 326.16, 'entropy = 0.0\nsamples = 36\nvalue = [0, 36, 0]\nclass = versicolor'),
#  Text(193.15384615384616, 326.16, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(515.0769230769231, 419.34857142857146, 'petal width (cm) <= 1.75\nentropy = 0.519\nsamples = 43\nvalue = [0, 5, 38]\nclass = virginica'),
#  Text(321.9230769230769, 326.16, 'petal length (cm) <= 4.95\nentropy = 1.0\nsamples = 8\nvalue = [0, 4, 4]\nclass = versicolor'),
#  Text(257.53846153846155, 232.9714285714286, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(386.3076923076923, 232.9714285714286, 'petal width (cm) <= 1.55\nentropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]\nclass = virginica'),
#  Text(321.9230769230769, 139.7828571428571, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = virginica'),
#  Text(450.69230769230774, 139.7828571428571, 'petal length (cm) <= 5.45\nentropy = 0.918\nsamples = 3\nvalue = [0, 2, 1]\nclass = versicolor'),
#  Text(386.3076923076923, 46.594285714285775, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(515.0769230769231, 46.594285714285775, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(708.2307692307693, 326.16, 'petal length (cm) <= 4.85\nentropy = 0.187\nsamples = 35\nvalue = [0, 1, 34]\nclass = virginica'),
#  Text(643.8461538461538, 232.9714285714286, 'sepal length (cm) <= 5.95\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(579.4615384615385, 139.7828571428571, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(708.2307692307693, 139.7828571428571, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(772.6153846153846, 232.9714285714286, 'entropy = 0.0\nsamples = 32\nvalue = [0, 0, 32]\nclass = virginica')]

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_test_pred)
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  0, 11]], dtype=int64)

# %%
confusion_matrix(y_train,y_train_pred)
# Out:
# array([[40,  0,  0],
#        [ 0, 41,  0],
#        [ 0,  0, 39]], dtype=int64)

# %%
y_train_pred=clf.predict(X_train)
y_test_pred=clf.predict(X_test)
print(confusion_matrix(y_train,y_train_pred))
print(confusion_matrix(y_test,y_test_pred))
# Out:
# [[40  0  0]
#  [ 0 41  0]
#  [ 0  0 39]]
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import
